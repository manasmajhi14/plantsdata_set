# %%
import pandas as pd

# %%
pd.set_option('display.max_rows',232)
pd.set_option('display.max_columns',1)

# %%
df = pd.read_excel("plants_data1.xlsx")

# %%
print(df)
# Out:
#                                            Chick peas:
# 0              1. Ascochyta Blight (Ascochyta rabiei):
# 1    Signs and Symptoms: Small, circular lesions wi...
# 2    Prevention and Management: Crop rotation, use ...
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# 10   2.Fusarium Wilt (Fusarium oxysporum f. sp. cic...
# 11   Signs and Symptoms: Yellowing and wilting of l...
# 12   Prevention and Management: Plant resistant var...
# 13                                                 NaN
# 14                                                 NaN
# 15                                                 NaN
# 16                                                 NaN
# 17           3. Botrytis Gray Mold (Botrytis cinerea):
# 18   * Signs and Symptoms: Grayish-brown mold on le...
# 19   * Prevention and Management: Avoid dense plant...
# 20                                                 NaN
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25                   4. Root Rots (Various pathogens):
# 26   * Signs and Symptoms: Stunted growth, yellowin...
# 27   * Prevention and Management: Ensure well-drain...
# 28                                                 NaN
# 29                                                 NaN
# 30                                                 NaN
# 31                                                 NaN
# 32                                                 NaN
# 33          5. Chickpea Chlorotic Dwarf Virus (CpCDV):
# 34   * Signs and Symptoms: Stunted growth, leaf yel...
# 35   * Prevention and Management: Use virus-free se...
# 36                                                 NaN
# 37                                                 NaN
# 38                                                 NaN
# 39                                                 NaN
# 40                                                 NaN
# 41                                                 NaN
# 42                                                 NaN
# 43                6. Rust (Uromyces ciceris-arietini):
# 44   * Signs and Symptoms: Small, reddish-brown pus...
# 45   * Prevention and Management: Plant resistant v...
# 46                                                 NaN
# 47                                                 NaN
# 48                                                 NaN
# 49                                                 NaN
# 50                                                 NaN
# 51                                                 NaN
# 52                                                 NaN
# 53             7. Alternaria Blight (Alternaria spp.):
# 54   * Signs and Symptoms: Brown to black lesions w...
# 55   * Prevention and Management: Plant disease-res...
# 56                                                   *
# 57                                                   *
# 58                                                 NaN
# 59                                                 NaN
# 60                                                 NaN
# 61                                                 NaN
# 62                                                TEA:
# 63                 Tea Leaf Rust (Hemileia vastatrix):
# 64   * Signs and Symptoms: Yellow to orange powdery...
# 65   * Prevention and Management: Plant resistant t...
# 66                                                 NaN
# 67                                                 NaN
# 68                                                 NaN
# 69              2. Tea Mosquito Bug (Helopeltis spp.):
# 70   * Signs and Symptoms: Feeding damage by nymphs...
# 71   * Prevention and Management: Regular monitorin...
# 72                                                 NaN
# 73                                                 NaN
# 74                                                 NaN
# 75                                                 NaN
# 76                                                 NaN
# 77                                                 NaN
# 78            3. Tea Yellow Blotch (Cephaleuros spp.):
# 79   * Signs and Symptoms: Yellow to orange circula...
# 80   * Prevention and Management: Maintain good can...
# 81                                                 NaN
# 82                                                 NaN
# 83                                                 NaN
# 84                                                 NaN
# 85     4. Tea Shot Hole Borer (Euwallacea fornicatus):
# 86   * Signs and Symptoms: Entry and exit holes on ...
# 87   * Prevention and Management: Implement proper ...
# 88                                                 NaN
# 89                                                 NaN
# 90                                                 NaN
# 91            5. Tea Green Leafhopper (Empoasca spp.):
# 92   * Signs and Symptoms: Feeding damage leads to ...
# 93   * Prevention and Management: Implement integra...
# 94                                                 NaN
# 95                                                 NaN
# 96                                             COFFEE:
# 97              Coffee Leaf Rust (Hemileia vastatrix):
# 98   * Signs and Symptoms: Orange to reddish-brown ...
# 99   * Prevention and Management: Plant resistant c...
# 100                                                NaN
# 101                                                NaN
# 102     2. Coffee Wilt Disease (Fusarium xylarioides):
# 103  * Signs and Symptoms: Sudden wilting and death...
# 104  * Prevention and Management: There is no cure ...
# 105                                                NaN
# 106                                                NaN
# 107                                                NaN
# 108                                                NaN
# 109   3. Coffee Root-Knot Nematode (Meloidogyne spp.):
# 110  * Signs and Symptoms: Stunted growth, yellowin...
# 111  * Prevention and Management: Practice crop rot...
# 112                                                NaN
# 113                                                NaN
# 114                                                NaN
# 115                                                NaN
# 116                 4. Coffee Ring Spot Virus (CoRSV):
# 117  * Signs and Symptoms: Mottled, ring-shaped pat...
# 118  * Prevention and Management: Plant virus-free ...
# 119                                                NaN
# 120                                                NaN
# 121  5. Coffee Brown Eye Spot (Cercospora coffeicola):
# 122  * Signs and Symptoms: Circular to irregular br...
# 123  * Prevention and Management: Maintain proper s...
# 124                                                  *
# 125                                                  *
# 126                                                NaN
# 127                                            COTTON:
# 128                                                NaN
# 129                                                NaN
# 130                  Cotton Leaf Curl Disease (CLCuD):
# 131                                                NaN
# 132  •\tSigns and Symptoms: Stunted growth, curling...
# 133  •\tPrevention and Management: Plant resistant ...
# 134                                                NaN
# 135                                                NaN
# 136       2. Verticillium Wilt (Verticillium dahliae):
# 137  * Signs and Symptoms: Yellowing and wilting of...
# 138  * Prevention and Management: Plant resistant c...
# 139                                                NaN
# 140                                                NaN
# 141                                                NaN
# 142  3. Bacterial Blight (Xanthomonas axonopodis pv...
# 143  * Signs and Symptoms: Water-soaked lesions on ...
# 144  * Prevention and Management: Plant disease-res...
# 145                                                  *
# 146                                                NaN
# 147                                                NaN
# 148            4. Cotton Boll Rot (Various pathogens):
# 149                                                  1
# 150  * Signs and Symptoms: Dark, sunken lesions on ...
# 151  * Prevention and Management: Harvest cotton at...
# 152                                                NaN
# 153                                                  *
# 154          5. Anthracnose (Colletotrichum gossypii):
# 155  * Signs and Symptoms: Circular to irregular da...
# 156  * Prevention and Management: Practice good fie...
# 157                                                NaN
# 158                                                NaN
# 159                                                NaN
# 160                                         SUGARCANE:
# 161          Sugarcane Smut (Sporisorium scitamineum):
# 162  * Signs and Symptoms: Formation of black, powd...
# 163  * Prevention and Management: Plant disease-fre...
# 164                                                NaN
# 165                                                NaN
# 166              2. Red Rot (Colletotrichum falcatum):
# 167  Signs and Symptoms: Reddish-brown internal dis...
# 168  Prevention and Management: Plant resistant var...
# 169                                                NaN
# 170                                                NaN
# 171            3. Sugarcane Yellow Leaf Virus (SCYLV):
# 172  * Signs and Symptoms: Yellowing and curling of...
# 173  * Prevention and Management: Use virus-free pl...
# 174                                                NaN
# 175                                                NaN
# 176                                                NaN
# 177                  4. Ratoon Stunting Disease (RSD):
# 178  * Signs and Symptoms: Stunted growth, short an...
# 179  * Prevention and Management: Use disease-free ...
# 180                                                NaN
# 181                                                NaN
# 182                                                NaN
# 183                                                NaN
# 184                                                NaN
# 185  5. Sugarcane Downy Mildew (Peronosclerospora s...
# 186  * Signs and Symptoms: White to grayish downy g...
# 187  * Prevention and Management: Plant resistant s...
# 188                                                NaN
# 189                                                NaN
# 190                                                NaN
# 191                                                NaN
# 192                                        VEGETABLES:
# 193                                                NaN
# 194   1. Tomato Blight (Early Blight and Late Blight):
# 195  * Signs and Symptoms: Early blight shows as da...
# 196  * Prevention and Management: Use disease-resis...
# 197                                                NaN
# 198                                                NaN
# 199                                                NaN
# 200                                                NaN
# 201                                  2.Powdery Mildew:
# 202  * Signs and Symptoms: White, powdery spots or ...
# 203  * Prevention and Management: Ensure good air c...
# 204                                                NaN
# 205                                                NaN
# 206                                                NaN
# 207  3. Aphid-Transmitted Viruses (e.g., Cucumber M...
# 208  * Signs and Symptoms: Stunted growth, yellowin...
# 209  * Prevention and Management: Control aphid vec...
# 210                                                NaN
# 211                                                NaN
# 212          4. White Mold (Sclerotinia sclerotiorum):
# 213  * Signs and Symptoms: Cottony white growth on ...
# 214  * Prevention and Management: Promote good air ...
# 215                                                NaN
# 216                                                NaN
# 217                                                NaN
# 218                                                NaN
# 219            5. Clubroot (Plasmodiophora brassicae):
# 220  * Signs and Symptoms: Swollen, club-like roots...
# 221  * Prevention and Management: Practice crop rot...
# 222                                                  *
# 223                                                NaN
# 224                                                NaN
# 225                                                NaN
# 226                                                NaN
# 227                                                NaN
# 228           6. Late Blight (Phytophthora infestans):
# 229  * Signs and Symptoms: Water-soaked lesions on ...
# 230  * Prevention and Management: Use disease-resis...

# %%
pd.set_option('display.max_rows',38)
pd.set_option('display.max_columns',2)

# %%
df = pd.read_excel("spices_data1.xlsx")

# %%
print(df)
# Out:
#                                                Spices
# 0                     1. Black Pepper (Piper nigrum):
# 1              * Major Disease: Phytophthora Foot Rot
# 2   * Symptoms: Yellowing of leaves, wilting, and ...
# 3   * Signs: Dark, sunken lesions at the base of t...
# 4   * Prevention: Improve soil drainage, avoid wat...
# 5                 2. Cardamom (Elettaria cardamomum):
# 6   * Major Disease: Cardamom Wilt (Thielaviopsis ...
# 7   * Symptoms: Wilting, yellowing of leaves, and ...
# 8         * Signs: Brown, rotting roots and rhizomes.
# 9   * Prevention: Plant disease-free rhizomes, pra...
# 10                       3. Turmeric (Curcuma longa):
# 11                         * Major Disease: Leaf Spot
# 12  * Symptoms: Small, dark lesions with yellow ma...
# 13                          * Signs: Spots on leaves.
# 14  * Prevention: Practice crop rotation, use dise...
# 15                   4. Chili Pepper (Capsicum spp.):
# 16  * Major Disease: Anthracnose (Colletotrichum s...
# 17  * Symptoms: Sunken, dark lesions with concentr...
# 18           * Signs: Fungal spore masses in lesions.
# 19  * Prevention: Use disease-resistant varieties,...
# 20                        5. Cumin (Cuminum cyminum):
# 21                      * Major Disease: Downy Mildew
# 22  * Symptoms: Yellowing of leaves, white or gray...
# 23  * Signs: Presence of downy mildew spores on th...
# 24  * Prevention: Use disease-free seed, practice ...
# 25                 6. Coriander (Coriandrum sativum):
# 26              * Major Disease: Cercospora Leaf Spot
# 27  * Symptoms: Circular, brown lesions with gray ...
# 28  * Signs: Presence of the Cercospora fungus on ...
# 29  * Prevention: Use disease-free seed, practice ...
# 30  7. Garlic (Allium sativum) and Onion (Allium c...
# 31  * Major Disease: Onion White Rot (Sclerotium c...
# 32  * Symptoms: Wilting, yellowing, and rotting of...
# 33  * Signs: Presence of small, round, white funga...
# 34  * Prevention: Rotate crops, use disease-free p...
# 35                                                NaN
# 36                                        Top of Form
